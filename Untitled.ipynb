# %%
import pandas as pd

data.df = pd.read_csv('SPtrans.csv')
print(data.df.head())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
# ----> 3 data.df = pd.read_csv('SPtrans.csv')
#       4 print(data.df.head())
#
# ...
